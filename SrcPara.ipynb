# %%
src_array= [
    {"src" : "shipments"},
    {"src" : "customers"},
    {"src" : "products"},
    {"src" : "warehouses"}
]

# %%
dbutils.jobs.taskValues.set(key = "output_key", value = src_array)
